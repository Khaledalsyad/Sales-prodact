# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r'C:\Users\Administrator\Desktop\Kagel\Sales Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1     1700.00
# 1           1    295666    LG Washing Machine                 1      600.00
# 2           2    295667  USB-C Charging Cable                 1       11.95
# 3           3    295668      27in FHD Monitor                 1      149.99
# 4           4    295669  USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 0  2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12
# 1  2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12
# 2  2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12
# 3  2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12
# 4  2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12
#
#      Sales            City  Hour
# 0  1700.00   New York City     0
# ...

# %%
df[['Price Each', 'Sales']]= df[['Price Each', 'Sales']].astype('int')

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# Order ID             int64
# Product             object
# Quantity Ordered     int64
# Price Each           int64
# Order Date          object
# Purchase Address    object
# Month                int64
# Sales                int64
# City                object
# Hour                 int64
# dtype: object

# %%
df.sample(10)
# Out:
#         Unnamed: 0  Order ID                     Product  Quantity Ordered  \
# 119228        2733    261962      27in 4K Gaming Monitor                 1
# 45253         1984    152394        USB-C Charging Cable                 1
# 60936         5701    167442            Wired Headphones                 1
# 124582        8112    267110      34in Ultrawide Monitor                 1
# 161869        3792    226534      AAA Batteries (4-pack)                 1
# 81900        11536    247702  Bose SoundSport Headphones                 1
# 158814         715    223597    Apple Airpods Headphones                 1
# 64877         9658    171233      AAA Batteries (4-pack)                 2
# 82952          580    194643      34in Ultrawide Monitor                 1
# 35453        10516    186597        USB-C Charging Cable                 1
#
#         Price Each           Order Date                      Purchase Address  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0       Order ID  Quantity Ordered     Price Each  \
# count  185950.000000  185950.000000     185950.000000  185950.000000
# mean     8340.388475  230417.569379          1.124383     183.653014
# std      5450.554093   51512.737110          0.442793     332.941600
# min         0.000000  141234.000000          1.000000       2.000000
# 25%      3894.000000  185831.250000          1.000000      11.000000
# 50%      7786.000000  230367.500000          1.000000      14.000000
# 75%     11872.000000  275035.750000          1.000000     150.000000
# max     25116.000000  319670.000000          9.000000    1700.000000
#
#                Month          Sales           Hour
# count  185950.000000  185950.000000  185950.000000
# mean        7.059140     184.751896      14.413305
# std         3.502996     333.125873       5.423416
# min         1.000000       2.000000       0.000000
# 25%         4.000000      11.000000      11.000000
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Day'] = df['Order Date'].dt.day
df['Month'] = df['Order Date'].dt.month
df['Year'] = df['Order Date'].dt.year

# %%
df.head()
# Out:
#    Unnamed: 0  Order ID               Product  Quantity Ordered  Price Each  \
# 0           0    295665    Macbook Pro Laptop                 1        1700
# 1           1    295666    LG Washing Machine                 1         600
# 2           2    295667  USB-C Charging Cable                 1          11
# 3           3    295668      27in FHD Monitor                 1         149
# 4           4    295669  USB-C Charging Cable                 1          11
#
#            Order Date                        Purchase Address  Month  Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12   1700
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12    600
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12     11
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12    149
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12     11
#
#              City  Hour  Day  Year
# ...

# %%
df['Total-sales'] = df['Quantity Ordered'] * df['Price Each']

# %%
group_prodact = df.groupby('Product')['Total-sales'].sum().sort_values()
print(group_prodact)
# Out:
# Product
# AAA Batteries (4-pack)          62034
# AA Batteries (4-pack)           82905
# Wired Headphones               226127
# USB-C Charging Cable           263725
# Lightning Charging Cable       325038
# LG Dryer                       387600
# LG Washing Machine             399600
# 20in Monitor                   450061
# Vareebadd Phone                827200
# 27in FHD Monitor              1124950
# Bose SoundSport Headphones    1332243
# Flatscreen TV                 1445700
# Apple Airpods Headphones      2349150
# 34in Ultrawide Monitor        2349421
# 27in 4K Gaming Monitor        2428916
# Google Phone                  3319200
# ThinkPad Laptop               4125870
# iPhone                        4794300
# Macbook Pro Laptop            8037600
# Name: Total-sales, dtype: int64

# %%
City_prodact = df.groupby('City')['Total-sales'].sum().sort_values()
print(City_prodact)
# Out:
# City
# Austin           1811054
# Portland         2309717
# Seattle          2735070
# Dallas           2755117
# Atlanta          2782841
# Boston           3644327
# New York City    4642872
# Los Angeles      5426973
# San Francisco    8223669
# Name: Total-sales, dtype: int64

# %%
City_prodact = df.groupby('Year')['Total-sales'].sum().sort_values()
print(City_prodact)
# Out:
# Year
# 2020        8640
# 2019    34323000
# Name: Total-sales, dtype: int64

# %%
City_prodact = df.groupby('Month')['Total-sales'].sum().sort_values()
print(City_prodact)
# Out:
# Month
# 1     1813956
# 9     2087435
# 2     2191696
# 8     2234194
# 6     2566187
# 7     2635443
# 3     2794068
# 5     3138287
# 11    3184394
# 4     3374951
# 10    3719205
# 12    4591824
# Name: Total-sales, dtype: int64

# %%
df.to_csv(r'C:\Users\Administrator\Desktop\New Date\Sales-Data.csv')
